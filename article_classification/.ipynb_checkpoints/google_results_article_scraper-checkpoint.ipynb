# %%
import urllib2  
from bs4 import BeautifulSoup
import sys
import time
from datetime import datetime
from nltk.corpus import stopwords
import string
import re
import pickle
import pandas as pd
import numpy as np
from nltk import word_tokenize
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.feature_extraction import text 
import matplotlib.pyplot as plt
from scipy.interpolate import spline

# %matplotlib inline

# %%
def get_headlines(quote_page):
    user_specs = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'
    user_specs2 = '"Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; Googlebot/2.1; +http://www.google.com/bot.html) Safari/537.36", "browser": { "name": "Safari" }, "engine": { "version": "537.36", "name": "WebKit" }, "os": {}, "device": {}, "cpu": {}'
    #quote_page = 'https://www.google.com/search?q=ebola&source=lnt&tbs=cdr%3A1%2Ccd_min%3A1%2F1%2F2015%2Ccd_max%3A3%2F31%2F2015&tbm=nws#q=ebola&tbs=cdr:1,cd_min:1/1/2015,cd_max:3/31/2015&tbm=nws&start=' + str(index)
  
    req = urllib2.Request(quote_page)
    req.add_header('User-Agent', user_specs)
    response = urllib2.urlopen(req)
    
    soup = BeautifulSoup(response, 'html.parser')  
    gs = soup.find_all(attrs={'class': 'g'})

    store = []
    for g in gs:
        print "\n"
        for i in g.stripped_strings:
            clean = i.encode('utf-8')
            store.append(clean)
            print clean
            
    return store


def create_url(query, month, day, year):
    url = 'https://www.google.com/search?q=' + str(query) + '&biw=1256&bih=699&source=lnt&tbs=cdr%3A1%2Ccd_min%3A' + str(month) + '%2F' + str(day) + '%2F' + str(year) + '%2Ccd_max%3A' + str(month) + '%2F' + str(day) + '%2F' + str(year) + '&tbm=nws'
    return url


def get_data(query):
    
    store = []
    for i in xrange(29,32):
        url = create_url(query, 7, i, 2014)
        store.append(url)
    for i in xrange(1,19):
        url = create_url(query, 8, i, 2014)
        store.append(url)
    
    headlines = []
    for i in store:
        one_day = get_headlines(i)
        headlines.append(one_day)
        time.sleep(np.random.randint(10,20))
        
    return headlines

# %%
results = get_data('ebola')
# Out:
# Where Does
# Ebola
# Come From?
# The Atlantic
# -
# Jul 29, 2014
# The worst
# Ebola
# virus outbreak ever is ravaging Liberia, Sierra Leone, and Guinea. So far, the disease has killed 670 people and infected more than 1,000, ...
# Why Deadly
# Ebola
# Virus Is Likely to Hit the US But Not Spread
# National Geographic
# -
# Jul 29, 2014
# Ebola
# outbreak: Asky bans flights in West Africa
# BBC News
# -
# Jul 29, 2014
# Public health adviser Yewande Adeshina said 30000 people at risk ...
# In-Depth
# -
# Daily Mail
# -
# Jul 29, 2014
# Ebola
# Politics
# Blog
# -
# Slate Magazine (blog)
# -
# Jul 29, 2014
# Ebola
# plane travel scare has officials on edge
# In-Depth
# -
# CBS News
# -
# Jul 29, 2014
# National Geographic
# Slate Magazine (blog)
# BBC News
# Telegraph.co.uk
# Daily Mail
# Forbes
# View all
#
#
# Azaria Marthyman,
# Ebola
# doctor, returns home to Victoria
# CBC.ca
# -
# Jul 29, 2014
# Dr. Azaria Marthyman, a Victoria doctor who was part of a medical group that travelled to Liberia earlier this month to treat victims of the
# Ebola
# virus has returned ...
# Victoria doctor places himself in quarantine after treating
# Ebola
# in ...
# International
# -
# Globalnews.ca
# -
# Jul 29, 2014
#
#
# Related Story: Doctor leading Sierra Leone's fight against
# Ebola
# ...
# ABC Online
# -
# Jul 29, 2014
# Ebola
# is believed to have killed 672 people in Guinea, Liberia and Sierra Leone since the outbreak began in February, according to the World Health ...
#
#
# Ebola
# conspiracy theories spreading fast as outbreak travels round ...
# Mirror.co.uk
# -
# Jul 29, 2014
# In Sierra Leone, which has the largest number of
# Ebola
# cases, thousands protested outside the country's main
# Ebola
# treatment facility in the eastern city of ...
#
#
# Ebola
# outbreak: Liberia suspends football
# BBC News
# -
# Jul 29, 2014
# Liberia has suspended all football activities in an effort to control the spread of the deadly
# Ebola
# virus. There was a risk of infection because football is a contact ...
# Ebola
# outbreak: More than doctors needed to contain West Africa's ...
# In-Depth
# -
# CBC.ca
# -
# Jul 29, 2014
#
#
# An
# Ebola
# Epidemic Will Not Happen in the US
# Reason (blog)
# -
# Jul 29, 2014
# Ebola
# SierraExpressMediaUSA Today features a slightly alarming headline:
# Ebola
# Only an Plane Ride Away from USA. Of course that is true, but that does ...
#
#
# NCAA Suspends Asky Airlines for Flying
# Ebola
# Virus Victim into ...
# Bella Naija
# -
# Jul 29, 2014
# IKEJA (NAN) ― Nigerian Civil Aviation Authority (NCAA) has suspended all ASky Airline flight operations to Nigeria over the transportation of an
# Ebola
# virus ...
#
#
# Ebola
# : 'It's close, it's at our front door'
# WND.com
# -
# Jul 29, 2014
# Patrick Sawyer, the infected man who boarded an international flight last week carrying the deadly
# Ebola
# virus and set off alarms about the disease escaping ...
#
#
# Can social media help prevent the spread of
# Ebola
# ?
# BBC News
# -
# Jul 29, 2014
# West Africa is in the grip of the world's deadliest outbreak of
# Ebola
# , and many in the region are using social media to educate each other on the symptoms and ...
#
#
# Ebola
# : Nigeria is not out of the woods yet — Prof. Tomori
# Vanguard
# -
# Jul 29, 2014
# Since the confirmation and subsequent death of a Liberian man who was the first to be diagnosed with the
# Ebola
# Virus Disease on Nigerian soil, anxiety, shock ...
#
#
# Ebola
# fears hit close to home
# CNN
# -
# Jul 30, 2014
# Sawyer is the first American to die in what health officials are calling the "deadliest
# Ebola
# outbreak in history." His death has sparked concerns that the virus ...
# Ebola
# : Spider's web of infection is growing as hunt continues for ...
# Mirror.co.uk
# -
# Jul 30, 2014
# 'We Need More': Fight Against
# Ebola
# Is Thin on the Ground
# In-Depth
# -
# NBCNews.com
# -
# Jul 30, 2014
# Congressman: Close Border to
# Ebola
# Countries
# Opinion
# -
# U.S. News & World Report
# -
# Jul 30, 2014
# Poverty is at the root of west Africa's
# ebola
# crisis
# Blog
# -
# Channel 4 News (blog)
# -
# Jul 30, 2014
# Ebola
# outbreak: US Peace Corps evacuates, Liberia closes schools
# In-Depth
# -
# CBC.ca
# -
# Jul 30, 2014
# U.S. News & World Report
# Mirror.co.uk
# CBS News
# ABC News
# Al Jazeera America
# Quartz
# View all
#
#
# Ebola
# virus: Risk of outbreak spreading to Australia is very low, chief ...
# ABC Online
# -
# Jul 30, 2014
# The risk of the deadly
# Ebola
# virus spreading to Australia from West Africa is very low, the Commonwealth chief medical officer has said. Almost 700 people have ...
#
#
# Within the next few days we will know if Kent Brantly and Nancy ...
# Daily Mail
# -
# Jul 30, 2014
# The two American doctors battling the
# Ebola
# virus are entering a 'critical' phase of their treatment, the head of the charity which sent them to Liberia has revealed ...
# American
# Ebola
# doctor 'terrified' after catching disease while trying ...
# Mirror.co.uk
# -
# Jul 30, 2014
# What you need to know about the
# Ebola
# virus
# wwlp.com
# -
# Jul 30, 2014
# Mirror.co.uk
# wwlp.com
# Huffington Post UK
# NBCNews.com
# View all
#
#
# EBOLA
# : Doctor Quarantined in Canada
# Breitbart News
# -
# Jul 30, 2014
# (AFP) — A Canadian doctor has put himself in quarantine as a precaution after spending weeks in West Africa treating patients with the deadly
# Ebola
# virus ...
#
#
# Ebola
# : NHS can deal with threat to UK, says Philip Hammond
# BBC News
# -
# Jul 30, 2014
# The UK's health services have the experience to deal with the threat posed by the
# Ebola
# virus, Foreign Secretary Philip Hammond has said. Mr Hammond said ...
# The death of a key doctor damages the fight against
# Ebola
# in Sierra ...
# Public Radio International
# -
# Jul 30, 2014
# View all
#
#
# Telegraph.co.uk
# Ebola
# outbreak: pan-African airline halts flights to west African ...
# The Guardian
# -
# Jul 30, 2014
# "The suspension of flights to Freetown and Monrovia by ASKY is related to the fight against the spread of the
# Ebola
# virus," said Afoussath Traore, a spokesman ...
# Ebola
# crisis: what is being done to stop the spread?
# Telegraph.co.uk
# -
# Jul 30, 2014
# Two American Missionaries Fighting for Life Against
# Ebola
# Virus ...
# Christian Post
# -
# Jul 30, 2014
# View all
#
#
# Ebola
# : Liberia shuts schools to tackle outbreak
# BBC News
# -
# Jul 30, 2014
# Liberia's government has announced that it is closing down all schools across the country to stop the spread of the deadly
# Ebola
# virus. Some communities would ...
#
#
# Ebola
# outbreak: British doctor tells how medics risk their lives to treat ...
# Mirror.co.uk
# -
# Jul 30, 2014
# A British doctor who went to treat
# Ebola
# victims in Africa has told how medics put ... Dozens of health workers have died treating
# Ebola
# patients and Dr Spencer ...
# Ebola
# survivor: 'I was terribly afraid'
# BBC News
# -
# Jul 30, 2014
# View all
#
#
# Canada 'concerned' over
# Ebola
# outbreak, but risk to country low ...
# CTV News
# -
# Jul 30, 2014
# As international health officials scramble to contain a deadly outbreak of
# Ebola
# in West Africa, Canadian border agents are now on alert for any signs of illness ...
#
#
# Official: Preliminary test of CMC patient shows malaria
# WSOC Charlotte
# -
# Jul 30, 2014
# Passaretti said they determined the patient did not have
# Ebola
# . The patient has been discharged home. 'There was great communication between hospital and ...
# Patient traveling from Africa prompts
# Ebola
# scare at CMC
# Charlotte Observer
# -
# Jul 30, 2014
# View all
#
#
# How the
# Ebola
# Outbreak Became Deadliest in History
# LiveScience.com
# -
# Jul 31, 2014
# The reasons why the
# Ebola
# outbreak in West Africa has grown so large, and why it is happening now, may have to do with the travel patterns of bats across ...
# WHO Director-General, west African presidents to launch intensified ...
# World Health Organization (press release)
# -
# Jul 31, 2014
# Seychelles out of Afcon 2015 race
# International
# -
# Sierra Express Media
# -
# Jul 31, 2014
# Source: Flight en route to Liberia to evacuate Americans infected ...
# In-Depth
# -
# Highly Cited
# -
# BBC News
# -
# Jul 31, 2014
# View all
#
#
# Nigerian official warns pastors and healers to stop making false ...
# Washington Post
# -
# Jul 31, 2014
# African governments are doubling down on efforts to contain the widening
# Ebola
# outbreak in West Africa, which also involves combating rumors and falsehoods ...
#
#
# PH has procedures to track, prevent
# Ebola
# spread — DOH
# Inquirer.net
# -
# Jul 31, 2014
# MANILA, Philippines — The deadly
# Ebola
# virus has reportedly infected some 1,200, mostly in West Africa where it has left at least 670 dead across the region ...
# DOH: Philippines ready for
# Ebola
# virus
# The Centrio Times
# -
# Jul 31, 2014
# View all
#
#
# American dies in Liberia as
# Ebola
# outbreak closes borders
# CBS News
# -
# Jul 31, 2014
# A young American man died Wednesday in Liberia, where an outbreak of the deadly
# Ebola
# virus has reached historic levels. But, his family said, it wasn't the ...
# Brother Of Md. Man Who Died In Liberia Remembers Final Words
# CBS Local
# -
# Jul 31, 2014
# View all
#
#
# Ebola
# crisis: Virus spreading too fast, says WHO
# BBC News
# -
# Aug 1, 2014
# The
# Ebola
# outbreak in West Africa is spreading faster than efforts to control it, World Health Organization (WHO) head Margaret Chan has said. She told a ...
# Ebola
# Virus Is Outpacing Efforts to Control It, World Health Body Warns
# New York Times
# -
# Aug 1, 2014
# WHO Warns of 'Catastrophic' Consequences of
# Ebola
# Wall Street Journal (India)
# -
# Aug 1, 2014
# Mapping the acceleration of
# Ebola
# in West Africa in five charts
# Quartz
# -
# Aug 1, 2014
# Exposure of health workers weakens Africa's
# Ebola
# fight
# In-Depth
# -
# Reuters
# -
# Aug 1, 2014
# Ebola
# moving faster than control efforts
# In-Depth
# -
# Daily Mail
# -
# Aug 1, 2014
# New York Times
# Wall Street Journal (India)
# Reuters
# Geek
# PLoS Blogs (blog)
# Daily Mail
# View all
#
#
# What we need to fight
# Ebola
# Washington Post
# -
# Aug 1, 2014
# Ebola
# outbreaks have occurred in Africa on more than two dozen occasions over the past 40 years, and they were brought under control every time. This was ...
# How
# Ebola
# spreads: Important facts on disease transmission
# The Post-Standard
# -
# Aug 1, 2014
# Parts of Africa are in the throes of the deadliest outbreak of
# Ebola
# in ...
# NBC4 Washington
# -
# Aug 1, 2014
# US Scrambles to Retrieve
# Ebola
# Patients
# In-Depth
# -
# NBCNews.com
# -
# Aug 1, 2014
# Ebola's
# frontline: Battling fear and deadly virus
# Opinion
# -
# CNN
# -
# Aug 1, 2014
# Official:
# Ebola
# virus 'extraordinarily unlikely' to spread in US
# In-Depth
# -
# Los Angeles Times
# -
# Aug 1, 2014
# The Post-Standard
# NBC4 Washington
# NBCNews.com
# Daily Mail
# Los Angeles Times
# Department of Defense
# View all
#
#
# Ebola
# Serum: Explaining the Americans' Experimental Treatments
# LiveScience.com
# -
# Aug 1, 2014
# This
# Ebola
# outbreak is the largest in history, and has so far claimed 729 lives in ... There are no treatments or vaccines available for
# Ebola
# , though several are in ...
# What Happens Once
# Ebola
# Patients Arrive in the US
# ABC News
# -
# Aug 1, 2014
# First
# Ebola
# case diagnosed in US: Here's why you don't need to panic
# In-Depth
# -
# WGCL-TV Atlanta
# -
# Aug 3, 2014
# US Doctor with
# Ebola
# Being Treated in Atlanta
# In-Depth
# -
# People Magazine
# -
# Aug 3, 2014
# Atlanta hospital deemed 1 of safest for
# Ebola
# care
# In-Depth
# -
# Daily Mail
# -
# Aug 3, 2014
# NPR
# ABC News
# WGCL-TV Atlanta
# RT
# People Magazine
# TIME
# View all
#
#
# Ebola
# outbreak: US experts to head to West Africa
# BBC News
# -
# Aug 3, 2014
# The US has announced plans to send at least 50 public health experts to West Africa to help fight the worst-ever outbreak of
# Ebola
# . A senior US health official ...
# CDC Director Says US 'Surging' Efforts to Stop
# Ebola
# Outbreak
# ABC News
# -
# Aug 3, 2014
# CDC director: "We can stop"
# Ebola
# from spreading
# CBS News
# -
# Aug 3, 2014
# Ebola
# : The disease is not the real problem
# Daily Maverick
# -
# Aug 3, 2014
# Are You Worried About an
# Ebola
# Outbreak in America? Check This ...
# Mic
# -
# Aug 3, 2014
# Terrorists could use
# Ebola
# to create dirty bomb to kill large numbers ...
# In-Depth
# -
# Daily Mail
# -
# Aug 3, 2014
# ABC News
# Daily Mail
# CBS News
# Daily Maverick
# Mic
# Independent Online
# View all
#
#
# Ebola
# terror at Gatwick as passenger collapses and dies getting off ...
# Mirror.co.uk
# -
# Aug 3, 2014
# Airport staff tonight told of their fears of an
# Ebola
# outbreak after a passenger from Sierra Leone collapsed and died as she got off a plane at Gatwick. Workers ...
# Ebola
# scare at Gatwick: Fears disease may reach Britain grow after ...
# Highly Cited
# -
# Daily Mail
# -
# Aug 3, 2014
#
#
# Ebola
# outbreak: US warns disease remains out of control as ...
# ABC Online
# -
# Aug 3, 2014
# The United States is sending an extra 50 public health officials to Africa to help combat the
# Ebola
# virus, warning that the outbreak remains out of control. Over the ...
#
#
# Ebola
# Isn't Likely to Spread Worldwide, Say Scientists
# Haaretz
# -
# Aug 3, 2014
# Ebola
# has captivated the world's attention because it's a terrifying disease – and the deadly haemorrhagic fever is caused by a virus, meaning there's no cure.
#
#
# Dr. Kent Brantly, stricken with
# Ebola
# , “appears to be improving ...
# fox6now.com
# -
# Aug 3, 2014
# ATLANTA (CNN) -- An American doctor infected with
# Ebola
# in Liberia "seems to be improving," according to the director of the Centers for Disease Control and ...
# Retired US doctor quarantines himself after treating
# Ebola
# in West ...
# New York's PIX11 / WPIX-TV
# -
# Aug 3, 2014
# View all
#
#
# LDS missionaries being moved in Africa due to
# Ebola
# virus
# KHON2
# -
# Aug 3, 2014
# (KSL/CNN) — Due to the outbreak of the
# Ebola
# virus, all Mormon missionaries serving in the African nations of Sierra Leone and Liberia are in the process of ...
#
#
# Ebola
# crisis: BBC visits affected village in Guinea
# BBC News
# -
# Aug 3, 2014
# Ebola
# crisis: BBC visits affected village in Guinea. 3 August 2014 Last updated at 12:54 BST. The
# Ebola
# virus has claimed almost 700 lives in West Africa, amid ...
#
#
# Ebola
# Outbreak Feeds on Fear, Anger, Rumors
# ABC News
# -
# Aug 3, 2014
# As the number of new infections and deaths rise in the
# Ebola
# outbreak, fear and suspicion is rising, too, making it more difficult for health care workers to get the ...
# Aug 6, 2014
# Daily Mail
# International Business Times
# Christian Post
# ChristianToday
# Los Angeles Times
# The Plain Dealer
# View all
#
#
# New York City hospital patient tests negative for
# Ebola
# CBS News
# -
# Aug 6, 2014
# The Centers for Disease Control and Prevention says three Americans in the United States have been tested for
# Ebola
# since the outbreak was first reported and ...
# Mount Sinai Hospital: Patient In Isolation Does Not Have
# Ebola
# CBS Local
# -
# Aug 6, 2014
# New York patient who went to Africa tests negative for
# Ebola
# Los Angeles Times
# -
# Aug 6, 2014
# View all
#
#
# Why do two white Americans get the
# Ebola
# serum while hundreds of ...
# Washington Post
# -
# Aug 6, 2014
# It consists of immune-boosting monoclonal antibodies that were extracted from mice exposed to bits of
# Ebola
# DNA. Now in isolation at an Atlanta hospital, they ...
# Tobacco-derived 'plantibodies' enter the fight against
# Ebola
# Reuters
# -
# Aug 6, 2014
# Ebola
# myths range from dumb to deadly: Our view
# Opinion
# -
# USA TODAY
# -
# Aug 6, 2014
# Ebola
# Tobacco Drug Joins Duckweed in Plant War on Disease
# In-Depth
# -
# Bloomberg
# -
# Aug 6, 2014
# View all
#
#
# Ebola
# Outbreak: Spanish Priest Infected by Killer Virus to be Treated ...
# International Business Times UK
# -
# Aug 6, 2014
# Ebola
# Medical staff put on protective gear before entering an
# Ebola
# treatment centre. Over 900 people have died of the virus in Liberia, Sierra Leone and Nigeria ...
# Religious Workers Risk Their Lives On The Frontline Of
# Ebola
# ...
# Huffington Post
# -
# Aug 6, 2014
# Ebola
# -Stricken Spanish Priest: Take Me Back, I Want To Be Treated ...
# Fox News Latino
# -
# Aug 6, 2014
# View all
#
#
# 'God is angry with Liberia,' local religious leaders say, blaming ...
# Washington Post
# -
# Aug 6, 2014
# There are local reports that “armed men” are allegedly trying to poison wells “to kill in the name of
# Ebola
# .” There are reports that the government is dumping ...
#
#
# Liberia declares state of emergency as
# Ebola
# death toll rises to 932
# RT
# -
# Aug 6, 2014
# Liberia's president declared a state of emergency on Wednesday to combat the ongoing outbreak of the deadly
# Ebola
# virus in West Africa, as the country began ...
# Relatives of
# Ebola
# victims are dragging their bodies onto streets of ...
# Daily Mail
# -
# Aug 6, 2014
# Liberia's president declares state of emergency amid
# Ebola
# ...
# National Post
# -
# Aug 6, 2014
# View all
#
#
# Ebola
# 'Experimental Serum' in Limited Supply, CDC Says
# LiveScience.com
# -
# Aug 6, 2014
# The "experimental serum" that doctors gave to two American patients with
# Ebola
# is in very limited supply, and will not be available for general use, according to ...
# Distribution map of
# Ebola
# cases, 1976-2014
# The Globe and Mail
# -
# Aug 6, 2014
# View all
#
#
# At a glance: Sierra Leone
# UNICEF (press release)
# -
# Aug 6, 2014
# As an outbreak of
# Ebola
# virus in West Africa continues to spread, health workers in Sierra Leone are risking their lives in the effort to contain the deadly disease.
#
#
# Putting the
# Ebola
# outbreak in context
# Redding Record Searchlight
# -
# Aug 6, 2014
# The world, and by the world we mean cable TV, is consumed by the news of an
# Ebola
# epidemic. To be sure, it's serious.
# Ebola
# has grown out of control in the ...
# Ann Coulter refers to Africa as “disease-ridden cesspool” in victim ...
# The Independent
# -
# Aug 7, 2014
# View all
#
#
# The Small Business That May Have Found a Cure for
# Ebola
# Inc.com
# -
# Aug 7, 2014
# Mapp Biopharmaceutical, a nine-person company based in San Diego, has produced a drug that's helping two Americans who have been diagnosed with
# Ebola
# ...
# Potential treatment for
# Ebola
# will take months to create
# New York Daily News
# -
# Aug 7, 2014
# How the Experimental
# Ebola
# Serum Is Being Grown Inside Tobacco ...
# Gizmodo
# -
# Aug 7, 2014
# View all
#
#
# Ebola
# Outbreak: Missionary Doctor Tells Congress 95% Of Doctors ...
# International Business Times
# -
# Aug 7, 2014
# RTR41CFW Volunteers carry bodies in a centre run by Medecins Sans Frontieres for
# Ebola
# patients in Kailahun July 18, 2014. Hundreds of troops were ...
# Ebola
# outbreak: Bodies 'dumped in the street' as Liberia faces panic ...
# In-Depth
# -
# Telegraph.co.uk
# -
# Aug 7, 2014
#
#
# Ebola
# Frontline: Sierra Leone's
# Ebola
# Epicenter is On Lockdown
# Newsweek
# -
# Aug 7, 2014
# All districts of Sierra Leone except one have recorded cases of
# Ebola
# , but the hardest hit are the districts of Kenema and Kailahun. Kenema is the third largest ...
# American Says 'Sense of Humanity' Makes Him Fight
# Ebola
# ABC News
# -
# Aug 7, 2014
# In This Very Challenged Region,
# Ebola
# Is Evolving Into a National ...
# Huffington Post UK
# -
# Aug 7, 2014
# View all
#
#
# Liberia:
# Ebola
# a plague from God due to sin
# WND.com
# -
# Aug 7, 2014
# As health officials worldwide spend hundreds of millions of dollars to bring under control an
# Ebola
# outbreak in several West African nations where nearly 1,000 ...
# Liberians Rally On Statehouse Steps For
# Ebola
# Aid
# Rhode Island Public Radio
# -
# Aug 7, 2014
# Ebola
# outbreak: Liberia - a country plagued by fear
# In-Depth
# -
# The Independent
# -
# Aug 7, 2014
# View all
#
#
# Exclusive: Liberia health system collapsing as
# Ebola
# spreads
# Reuters
# -
# Aug 7, 2014
# A Samaritan's Purse medical personnel demonstrates personal protective equipment to educate volunteers on the
# Ebola
# virus in Liberia, in this undated handout ...
# Ebola
# outbreak: Liberia's health care system 'collapsing' amid ...
# The Independent
# -
# Aug 7, 2014
# Libera's health system collapsing due to
# Ebola
# New York Daily News
# -
# Aug 7, 2014
# View all
#
#
# Ebola
# outbreak: Spanish priest evacuated from Liberia
# BBC News
# -
# Aug 7, 2014
# A Spanish missionary infected with
# Ebola
# while working in Liberia has returned home, after Liberia's president declared a state of emergency over the the ...
#
#
# BBC News
# WHO:
# Ebola
# outbreak in West Africa an international health ...
# CNN
# -
# Aug 8, 2014
# Global health experts on Friday declared the
# Ebola
# epidemic ravaging West Africa an international health emergency that requires a coordinated global ...
# WHO:
# Ebola
# 'an international emergency'
# BBC News
# -
# Aug 8, 2014
# UN Agency Calls
# Ebola
# Outbreak an International Health Emergency
# In-Depth
# -
# New York Times
# -
# Aug 8, 2014
# WHO Declares Public Health Emergency as
# Ebola
# Case ...
# Opinion
# -
# U.S. News & World Report
# -
# Aug 8, 2014
# Apocalypse now? Some reassuring facts from the congressional ...
# Blog
# -
# Washington Post (blog)
# -
# Aug 8, 2014
# Why the Americans Got the
# Ebola
# Serum
# In-Depth
# -
# Daily Beast
# -
# Aug 8, 2014
# New York Times
# Science Magazine
# Daily Beast
# Business Insider
# TIME
# World Health Organization (press release)
# View all
#
#
# Ebola
# Outbreak Is A Global Health Emergency, WHO Says
# NPR
# -
# Aug 8, 2014
# The
# Ebola
# outbreak in West Africa won't be stopped until front-line health workers get more support, World Health Organization Director-General Dr. Margaret ...
# WHO declares
# Ebola
# epidemic an international health emergency
# Reuters
# -
# Aug 8, 2014
# Ebola
# outbreak declared a public health emergency by World Health ...
# Fox News
# -
# Aug 8, 2014
# MSF operational update for
# Ebola
# outbreak in west Africa
# Médecins Sans Frontières (MSF) International
# -
# Aug 8, 2014
# Should Patients Be Given Experimental
# Ebola
# Drugs?
# Discover Magazine (blog)
# -
# Aug 8, 2014
# UN:
# Ebola
# outbreak a public health emergency
# In-Depth
# -
# Daily Mail
# -
# Aug 8, 2014
# Reuters
# Fox News
# Médecins Sans Frontières (MSF) International
# Discover Magazine (blog)
# Daily Mail
# BBC News
# View all
#
#
# Ebola
# -infected American doctor releases statement from isolation: 'I ...
# Fox News
# -
# Aug 8, 2014
# Dr. Kent Brantly, the American doctor infected with
# Ebola
# released a statement Friday afternoon— his first since being brought back to the U.S..
# First Statement From
# Ebola
# Patient: 'I Am Growing Stronger'
# NBCNews.com
# -
# Aug 8, 2014
# Ann Coulter, Donald Trump
# Ebola
# Comments Prompt Christian ...
# Huffington Post
# -
# Aug 8, 2014
# View all
#
#
# Intl health emergency: WHO issues
# Ebola
# warning
# RT
# -
# Aug 8, 2014
# The
# Ebola
# outbreak in West Africa is an "extraordinary event", which poses a public health risk to other states, the World Health Organization said, urging global ...
# Precautions taken with patient at Brampton hospital with
# Ebola
# -like ...
# CP24 Toronto's Breaking News
# -
# Aug 8, 2014
# Ontario hospital treating patient for
# Ebola
# -like symptoms
# Globalnews.ca
# -
# Aug 8, 2014
# Brampton Civic Hospital's patient sparks
# Ebola
# worries
# Opinion
# -
# Toronto Star
# -
# Aug 8, 2014
# View all
#
#
# Treating
# Ebola
# in Sierra Leone: 'We are two steps behind'
# CNN
# -
# Aug 8, 2014
# Sierra Leone's government demanded a shutdown and its citizens are listening. The West African nation crippled by
# Ebola
# is responding to the outbreak through ...
# In traumatized Liberia, Sierra Leone and Guinea,
# Ebola
# chaos
# Washington Post
# -
# Aug 8, 2014
# Aid Worker Speaks Out On Why
# Ebola
# Keeps Spreading
# Huffington Post
# -
# Aug 8, 2014
# View all
#
#
# To use ZMapp or not
# The Hindu
# -
# Aug 8, 2014
# The decision to use an experimental drug to treat two Americans infected with
# Ebola
# , while nearly 1,000 Africans have already died from the deadly epidemic, ...
# Scientist developing serum from tobacco plants to fight
# Ebola
# WLWT Cincinnati
# -
# Aug 8, 2014
# US
# Ebola
# Victims Responding To 'Experimental' Serum
# SpaceCoastDaily.com
# -
# Aug 8, 2014
# View all
#
#
# India on Alert for
# Ebola
# Virus, Health Minister Outlines Plan
# NDTV
# -
# Aug 8, 2014
# Volunteers prepare to remove the bodies of people who were suspected of contracting
# Ebola
# and died in the community in the village of Pendebu, north of ...
# India goes on alert for
# Ebola
# , with thousands of nationals in West ...
# Reuters India
# -
# Aug 8, 2014
# View all
#
#
# A Company That Makes an
# Ebola
# Drug Just Saw Its Stock Surge
# TIME
# -
# Aug 8, 2014
# The switch could allow potential use of the drug on
# Ebola
# -infected patients for what the World Health Organization has said is a global public health emergency.
# The Best Investment For The Fight Against
# Ebola
# NASDAQ
# -
# Aug 8, 2014
# BC's Tekmira gets FDA approval to fast track
# Ebola
# drug
# CBC.ca
# -
# Aug 8, 2014
# View all
#
#
# How the
# Ebola
# virus outbreak could 'wreck' Liberia's economy
# The Observers
# -
# Aug 8, 2014
# Liberia is desperately trying to grapple with an outbreak of the deadly
# Ebola
# virus. As the country struggles to recover from years of devastating conflict, our ...
# People are struggling to bury the
# Ebola
# dead
# Helsinki Times
# -
# Aug 8, 2014
# View all
#
#
# Inside the Flying Quarantine Ward Used to Transport
# Ebola
# Patients
# Wired
# -
# Aug 8, 2014
# The
# Ebola
# virus wracking his body had progressed to the hemorrhagic stage; Brantly's vomit and stool were bloody. But now, after a dose of an experimental ...
# Cartersville air crews trained for
# Ebola
# transport
# Rome News-Tribune
# -
# Aug 8, 2014
# View all
#
#
# You Asked Questions About
# Ebola
# — And We Have Answers
# NPR
# -
# Aug 9, 2014
# This week, we asked our readers for questions they have about the
# Ebola
# outbreak in West Africa. For answers to some of the queries, we turned to Dr. Darin ...
# Guinea closes borders over
# Ebola
# outbreak
# Aljazeera.com
# -
# Aug 9, 2014
# West African nations try to contain
# Ebola
# CNN
# -
# Aug 9, 2014
# Liberian President Apologizes to Health Care Workers for
# Ebola
# ...
# NBCNews.com
# -
# Aug 9, 2014
# Liberians demand that govt picks up
# Ebola
# bodies
# Yahoo News
# -
# Aug 9, 2014
# Aljazeera.com
# NBCNews.com
# Yahoo News
# New York's PIX11 / WPIX-TV
# CBS News
# myfox8.com
# View all
#
#
# US
# Ebola
# Victim Writes Message From Isolation
# Sky News
# -
# Aug 9, 2014
# An American doctor being treated for
# ebola
# has revealed he is "growing stronger every day" in an emotional statement from his isolation room. Aid worker Kent ...
#
#
# Ebola
# ...
# Nigeria's revolutionary salute stalls
# Ebola
# BBC News
# -
# Aug 14, 2014
# South Africa steps up
# Ebola
# response
# Health24.com
# -
# Aug 14, 2014
# View all
#
#
# Why should two white missionaries get the first
# Ebola
# treatments?
# Los Angeles Times
# -
# Aug 14, 2014
# Two American missionary medical workers stricken by
# Ebola
# in Liberia were the first to receive a scarce, experimental treatment drug. And now the question ...
# Emory Doctor Reflects on Treating
# Ebola
# Patients
# WABE 90.1 FM
# -
# Aug 14, 2014
# View all
#
#
# A Fiasco At The Burial Ground, A Prank At The Shop: Covering
# Ebola
# NPR
# -
# Aug 14, 2014
# En route to Liberia to cover the
# Ebola
# outbreak, he flew out of Sierra Leone's Freetown airport. Like all passengers, he had his body temperature measured by ...
#
#
# Korean Air suspends Kenya flights over
# Ebola
# Aljazeera.com
# -
# Aug 14, 2014
# Time to cut the hype and focus on the real dangers of
# Ebola
# Opinion
# -
# Washington Post
# -
# Aug 17, 2014
# Ebola
# Out of Control: Quarantines, Hunger and Death in Liberia
# In-Depth
# -
# Newsweek
# -
# Aug 17, 2014
# CBS News
# Business Insider
# Washington Post
# The Guardian
# Newsweek
# Reuters UK
# View all
#
#
# Ebola
# outbreak: Millionaire preacher TB Joshua 'sends 4000 bottles ...
# The Independent
# -
# Aug 17, 2014
# The World Health Organisation has discouraged people in affected areas from believing claims that certain products or practices can prevent or cure
# Ebola
# .
# Ebola
# is manufactured by Satan – TB Joshua
# DailyPost Nigeria
# -
# Aug 17, 2014
# View all
#
#
# Ebola
# outbreak: the doctor who came back from the dead
# Telegraph.co.uk
# -
# Aug 17, 2014
# Dr Melvin Korkor was one of six members of staff at Liberia's remote Phebe Hospital to contract the
# Ebola
# virus last month, he is the only one still alive today.
#
#
# Inside
# Ebola
# hell: Mirrorman witnesses horror of bodies being tipped ...
# Mirror.co.uk
# -
# Aug 17, 2014
# In a macabre scene, the corpses of seven other
# Ebola
# victims – including a ... Here in the hellish
# Ebola
# zone of West Africa, the victims' remains have to be ...
#
#
# Ebola
# virus is a danger to the world, not just Africa
# Herald Sun
# -
# Aug 17, 2014
# So far, 960 people have died in west Africa from the
# Ebola
# virus, probably the world's most virulent disease. Thousands have seen friends and relatives die.
# The
# Ebola
# Virus – Are You at Risk? [INFOGRAPHIC]
# ValueWalk
# -
# Aug 17, 2014
# View all
#
#
# Airborne transmission of
# Ebola
# RenewAmerica
# -
# Aug 17, 2014
# Many people have been mis-informed regarding human to human transmission of
# Ebola
# . The Canadian Health Dept. States that airborne transmission of
# Ebola
# ...
#
#
# OFWs in Nigeria 'more concerned' on job stability than
# Ebola
# Inquirer.net
# -
# Aug 17, 2014
# MANILA, Philippines—The recent inclusion of Nigeria among the West African nations battling the deadly
# Ebola
# virus alarmed the 7,000 Filipino workers ...
# Nigerian Medical Doctor Survives
# Ebola
# , Discharged From ...
# SaharaReporters.com
# -
# Aug 17, 2014
# View all
#
#
# Scientists racing to test
# Ebola
# vaccines in humans
# Jamaica Observer
# -
# Aug 17, 2014
# WASHINGTON, USA (AP) — Scientists are racing to begin the first human safety tests of two experimental
# Ebola
# vaccines, but it won't be easy to prove that the ...
#
#
# Ebola
# scare in Spanish coastal resort popular with British tourists
# Mirror.co.uk
# -
# Aug 17, 2014
# An
# Ebola
# scare has taken place in a Spanish coastal resort popular with British tourists. Health chiefs in Alicante, Spain, have activated their alert protocols after ...
#
#
# Ebola
# patients flee as Liberia clinic looted
# Aljazeera.com
# -
# Aug 17, 2014
# An
# Ebola
# quarantine centre in Liberia has been looted by a gang who reportedly took bloodstained sheets and forced 17 patients to flee, raising the chances of ...
#
#
# The
# Ebola
# outbreak: Is it safe to travel?
# Fox News
# -
# Aug 18, 2014
# The outbreak of
# Ebola
# in Western Africa has struck fear into visitors to the region. The disease has a fatality rate of up to 90 percent, so travelers need to ...
# New Mexico teacher, 30, is tested for
# Ebola
# after returning from ...
# Daily Mail
# -
# Aug 18, 2014
# Ebola
# : UN health agency requests exit screening of travellers ...
# UN News Centre
# -
# Aug 18, 2014
# Fear & loathing in Liberia as
# Ebola
# 'plague villages' pop up in ...
# In-Depth
# -
# RT
# -
# Aug 18, 2014
# Looters Attack Liberia
# Ebola
# Quarantine Center
# Blog
# -
# Slate Magazine (blog)
# -
# Aug 18, 2014
# Why the escape of numerous
# Ebola
# patients in Liberia's worst slum ...
# In-Depth
# -
# Washington Post
# -
# Aug 18, 2014
# Daily Mail
# UN News Centre
# TIME
# RT
# KOAT Albuquerque
# Washington Post
# View all
#
#
# Doctors worldwide should stay current on developments in
# Ebola
# ...
# Emory University News and Events
# -
# Aug 18, 2014
# Physicians at Emory University Hospital spoke Aug. 1, 2014 at a news briefing about
# Ebola
# patients being treated in a special isolation facility.
#
#
# Medical workers cope with fear and deadly
# Ebola
# virus
# USA TODAY
# -
# Aug 18, 2014
# LONDON — Doctors and nurses fighting
# Ebola
# in West Africa are working 14-hour days, seven days a week, wearing head-to-toe gear in the heat of muddy ...
#
#
# Caring For The American
# Ebola
# Patients: Inside Emory's Isolation Unit
# NPR
# -
# Aug 18, 2014
# When it comes to deadly, contagious disease outbreaks like
# Ebola
# , the terms "quarantine" and "isolation" take on fresh relevance and urgency. Each has a ...
#
#
# MSF Begins Admitting Patients to
# Ebola
# Center in Monrovia, Liberia
# Doctors Without Borders
# -
# Aug 18, 2014
# Doctors Without Borders/Médecins Sans Frontières (MSF) admitted nine patients today into its newly constructed ELWA 3
# Ebola
# Management Center in ...
#
#
# Ebola
# Unlikely to Spread on Planes, Health Agency Says
# LiveScience.com
# -
# Aug 18, 2014
# The chance that a person with
# Ebola
# will spread the disease on an airplane is ... "The risk of transmission of
# Ebola
# virus disease during air travel is low," the ...
#
#
# Ebola
# in India? Delhi Airport Sets up Quarantine Facility for ...
# International Business Times, India Edition
# -
# Aug 18, 2014
# A health facility to quarantine passengers who show symptoms of the
# Ebola
# virus has finally been set up at the Indira Gandhi International Airport (IGIA) in New ...
#
#
# Dying Sierra Leone Dr. Sheik Umar Khan never told
# Ebola
# drug was ...
# CBC.ca
# -
# Aug 18, 2014
# Dying Sierra Leone Dr. Sheik Umar Khan never told
# Ebola
# drug was available ... he tested positive for
# Ebola
# on July 22 and died in seven terrible days.
#
#
# Airlines Urged to Heed WHO on
# Ebola
# So Flights Continue
# Bloomberg
# -
# Aug 18, 2014
# Air links should be maintained with
# Ebola
# -hit regions in West Africa that need connections to the outside world, the International Air Transport Association said ...
#
#
# New Drugs and Vaccines Can't Stop This
# Ebola
# Outbreak
# Mother Jones
# -
# Aug 18, 2014
# With the death toll in the worst
# Ebola
# outbreak in history exceeding 1,000, pharmaceutical companies and health authorities are sprinting to develop new drugs ...

# %%
def cleanup(data):
    joined = ','.join(data)
    clean_view = joined.replace("View all", "")
    spaced = clean_view.replace(",", " ")
    splitlis = re.split(r'\s\s(201\d{1})', spaced)
    articles = [ x + " " + y for x,y in zip(splitlis[0::2], splitlis[1::2]) ]
    return articles

def clean_and_flatten(data):
    cleaned_data = []
    for i in data:
        cleaned_data.append(cleanup(i))
    flat = [item for sublist in cleaned_data for item in sublist]
    return flat

clean_and_flatten(results)

# %%
# save with pickle
with open('jul28aug18.pickle', 'wb') as handle:
    pickle.dump(flat_cleaned_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('jul28aug18.pickle', 'rb') as handle:
  b = pickle.load(handle)

# %%
news_sources = ['Scientific American', 'The Independent', 'Wall Street Journal', 'Aljazeera.', 'Washington Times', 
                'The Guardian', 'NBC', 'news', 'NBCNews.com', 'News', 'National Geographic', 'Slate Magazine',  
                'Aljazeera.com', 'Al Jazeera', 'Daily Mail', 'CBS', 'Yahoo', 'USA TODAY','blog', 'Blog', 'NPR', 'BBC', 
                'Huffington Post', 'ABC', 'CNN', 'TIME', 'New York Times', 'Los Angeles Times', 'Atlantic', 'Magazine', 
                'Washington Post', 'Mirror.co.uk', 'CBS News', 'CBC.ca', 'Fox', 'Telegraph.co.uk', 'Times', 'Reuters', 
                'Bloomberg', 'Toronto Star', 'The Streetjournal', 'New York Daily', 'Telegraph.co.uk', 
                'LiveScience.', 'International Business', 'Baltimore Sun', 'Mother Jones', 'SaharaReporters.com', 
                'The Globe and Mail', 'Daily Beast', 'Chicago Tribune', 'Business Insider', 'com']

def remove_news(line):
    for i in news_sources:
        line = line.replace(i, '')
    return line

no_news = map(remove_news, b)

# %%
def str_decode(string):
    return string.decode('utf-8')

def render_date(string):
    return datetime.strptime(string, '%b %d %Y')

df = pd.DataFrame(no_news, columns=['col'])
df = df['col'].str.rsplit(' - ', 1, expand=True)
df.columns = ['headline', 'date']
df = df.dropna(0)
df['headline'] = df['headline'].apply(str_decode)
df['date'] = df['date'].apply(render_date)


print df['date'].value_counts()
df.tail()
# Out:
# 2014-08-07    35
# 2014-08-05    34
# 2014-08-04    34
# 2014-08-08    34
# 2014-08-06    32
# 2014-08-12    29
# 2014-07-31    28
# 2014-08-13    27
# 2014-08-11    26
# 2014-08-01    26
# 2014-08-14    26
# 2014-08-10    26
# 2014-08-15    24
# 2014-08-03    23
# 2014-07-30    22
# 2014-08-16    21
# 2014-08-02    21
# 2014-08-09    18
# 2014-08-17    18
# 2014-07-29    17
# 2014-08-18    15
# Name: date, dtype: int64
#                                               headline       date
# 537   Doctors Without Borders/Médecins Sans Frontiè... 2014-08-18
# 538   The chance that a person with Ebola will spre... 2014-08-18
# 539   A health facility to quarantine passengers wh... 2014-08-18
# 540   Dying Sierra Leone Dr. Sheik Umar Khan never ... 2014-08-18
# 541   Air links should be maintained with Ebola -hi... 2014-08-18

# %%
#tfidf clusters
def clusters_tfidf2(df, clusters_count = 7):
    vect = TfidfVectorizer(max_df = 0.1, max_features = None,
                                 stop_words = text.ENGLISH_STOP_WORDS.union(['ebola']),
                                 use_idf = True, tokenizer = None, ngram_range=(1, 1))
    matrix = vect.fit_transform(df['headline']) 
    terms = vect.get_feature_names()
    km = KMeans(n_clusters = clusters_count, random_state=3)
    km.fit(matrix)
    clusters = km.labels_.tolist()
    order_centroids = km.cluster_centers_.argsort()[:, ::-1]
    store = []
    for i in range(clusters_count):
        cluster_num = "Cluster %d:" % (i + 1)
        topics = ', '.join([terms[ind] for ind in order_centroids[i, :8]])
        cluster_topics = cluster_num + ' ' + topics
        store.append(cluster_topics)
    return store

# %%
my_topics = clusters_tfidf2(df)
my_topics
# Out:
# [u'Cluster 1: opinion, report, world, know, crisis, deadly, border, emergency',
#  u'Cluster 2: hospital, experimental, drug, nigeria, india, emergency, serum, vaccine',
#  u'Cluster 3: leone, sierra, african, guinea, crisis, deadly, contain, nations',
#  u'Cluster 4: drugs, experimental, ethics, ethical, use, says, patients, untested',
#  u'Cluster 5: american, doctor, second, atlanta, arrives, kent, infected, brantly',
#  u'Cluster 6: people, new, disease, quarantine, york, world, ward, inside',
#  u'Cluster 7: spanish, priest, madrid, treated, infected, pajares, miguel, dies']

# %%
def create_lexicon(clusters):
    
    # create lexicon dictionary
    num_of_topics = len(clusters)
    df_ = pd.DataFrame(index=['df-init'], columns= [i+1 for i in range(num_of_topics)])

    for i in range(num_of_topics):
        cluster_i = (clusters[i])
        cluster_i = cluster_i.split(': ', 1)[1]
        cluster_i = cluster_i.split(',')
        df = pd.DataFrame(index=cluster_i, columns = [j+1 for j in range(num_of_topics)])
        for j in range(1+num_of_topics):
            if j == i:
                df[j+1] = 1
            else:
                df[j+1] = 0
        df_=df_.append(df)
    
    df_ = df_.drop(num_of_topics+1,1)
    df_ = df_.drop('df-init')
    
    return df_

# %%
def create_cluster_dict(clusters):
    
    # create cluster dictionary dataframe
    # intermediate object, discarded
    lex = pd.DataFrame(clusters, columns=['col'])
    lex = lex['col'].str.split(' ', 1, expand=True)
    lex = lex[1].str.rsplit(':', -1, expand=True)
    lex.columns = ['cluster', 'topics']
    
    # create cluster dictionary
    cluster_dict = lex.set_index('cluster').to_dict()
    cluster_dict = cluster_dict['topics']
    
    return cluster_dict

cluster_dict = create_cluster_dict(my_topics)

# %%
def my_tokenize(x):
        try:
            return word_tokenize(x)
        except UnicodeDecodeError:
            pass


def stopword_remove(x):
    stop_words = set(stopwords.words('english')).union(['ebola']) 
    list_of_words = [i.lower() for i in x if i.lower() not in stop_words]
    return list_of_words


def tokenize_and_stop(df):
    df['headline'] = df['headline'].apply(my_tokenize)
    df['headline'] = df['headline'].apply(stopword_remove)
    df['number of tokens'] = df['headline'].apply(len)
    return df


tokenize_and_stop(df)
# Out:
#                                             headline       date  \
# 0                                          [come, ?] 2014-07-29
# 1  [worst, virus, outbreak, ever, ravaging, liber... 2014-07-29
# 2   [outbreak, :, asky, bans, flights, west, africa] 2014-07-29
# 3  [public, health, adviser, yewande, adeshina, s... 2014-07-29
# 4                                [politics, -, (, )] 2014-07-29
#
#    number of tokens
# 0                 2
# 1                25
# 2                 7
# 3                12
# 4                 4

# %%
# ngrams for later
from nltk import ngrams
sentence = 'this is a foo bar sentences and i want to ngramize it'
n = 2
sixgrams = ngrams(sentence.split(), n)
mystore = []
for grams in sixgrams:
    mystore.append(grams)
    print grams
    
# join tuple
joined = ','.join(asdf)
spaced = joined.replace(",", ' ')
spaced
# Out:
# ('this', 'is')
# ('is', 'a')
# ('a', 'foo')
# ('foo', 'bar')
# ('bar', 'sentences')
# ('sentences', 'and')
# ('and', 'i')
# ('i', 'want')
# ('want', 'to')
# ('to', 'ngramize')
# ('ngramize', 'it')

# %%
def clustercount(df, cluster):
    col = []
    for line in df:
        count = 0
        for word in line:
            if word in cluster_dict[str(cluster)]:
                count = count + 1
        col.append(count)
    return col

# for each emotion, create a column with the number of words matching that emotion in a given tweet, then a ratio of the number of words
# matching that emotion against the total number of words in the tweet

def count_and_ratio(df):
    for i in xrange(1,len(my_topics)+1):
        df.loc[:, i] = clustercount(df['headline'], i)
        df.loc[:, str(i) + " hl ratio"] = df[i] / df['number of tokens']
    return df

count_and_ratio(df)
# Out:
#                                             headline       date  \
# 0                                          [come, ?] 2014-07-29
# 1  [worst, virus, outbreak, ever, ravaging, liber... 2014-07-29
# 2   [outbreak, :, asky, bans, flights, west, africa] 2014-07-29
# 3  [public, health, adviser, yewande, adeshina, s... 2014-07-29
# 4                                [politics, -, (, )] 2014-07-29
#
#    number of tokens  1  1 hl ratio  2  2 hl ratio  3  3 hl ratio  4  \
# 0                 2  0        0.00  0         0.0  0    0.000000  0
# 1                25  1        0.04  0         0.0  4    0.160000  1
# 2                 7  0        0.00  0         0.0  1    0.142857  0
# 3                12  0        0.00  0         0.0  0    0.000000  0
# 4                 4  0        0.00  0         0.0  0    0.000000  0
#
#    4 hl ratio  5  5 hl ratio  6  6 hl ratio  7  7 hl ratio
# 0        0.00  0        0.00  0    0.000000  0        0.00
# 1        0.04  1        0.04  2    0.080000  1        0.04
# 2        0.00  0        0.00  0    0.000000  0        0.00
# 3        0.00  0        0.00  1    0.083333  0        0.00
# 4        0.00  0        0.00  0    0.000000  0        0.00

# %%
def group_date_and_ratio(df):
    grouped_by_date = df.groupby('date').sum()
    grouped_by_date
    for i in xrange(1,len(my_topics)+1):
        grouped_by_date.loc[:, str(i) + " date ratio"] = grouped_by_date[i] / grouped_by_date['number of tokens']
    return grouped_by_date
    
grouped_by_date = group_date_and_ratio(df)
# Out:
#             number of tokens   1  1 hl ratio   2  2 hl ratio   3  3 hl ratio  \
# date
# 2014-07-29               282   5    0.207085   2    0.075736  17    0.907255
# 2014-07-30               363  15    1.055769   2    0.085455  15    0.766013
# 2014-07-31               411  16    1.131131  12    1.362637  21    1.311610
# 2014-08-01               352   9    0.722350   7    0.685775  14    1.121958
# 2014-08-02               291   9    1.144017   2    0.333333  16    1.412019
#
#              4  4 hl ratio   5      ...       6 hl ratio  7  7 hl ratio  \
# date                                ...
# 2014-07-29   2    0.206667   6      ...         0.372085  3    0.121940
# 2014-07-30  10    0.461119  13      ...         0.271999  4    0.155499
# 2014-07-31  12    0.882400  12      ...         0.082492  5    0.380909
# 2014-08-01  15    1.545092   6      ...         0.284674  1    0.043478
# 2014-08-02   7    0.740397  27      ...         0.342747  6    0.246812
#
#             1 date ratio  2 date ratio  3 date ratio  4 date ratio  \
# date
# 2014-07-29      0.017730      0.007092      0.060284      0.007092
# 2014-07-30      0.041322      0.005510      0.041322      0.027548
# 2014-07-31      0.038929      0.029197      0.051095      0.029197
# 2014-08-01      0.025568      0.019886      0.039773      0.042614
# 2014-08-02      0.030928      0.006873      0.054983      0.024055
#
#             5 date ratio  6 date ratio  7 date ratio
# date
# 2014-07-29      0.021277      0.028369      0.010638
# 2014-07-30      0.035813      0.013774      0.011019
# 2014-07-31      0.029197      0.004866      0.012165
# 2014-08-01      0.017045      0.019886      0.002841
# 2014-08-02      0.092784      0.017182      0.020619
#
# [5 rows x 22 columns]

# %%
def plot_line_graph(df):   
    plt.figure(figsize = (20, 8))
    plt.title('Headline Clusters', fontsize = 20)
    for i in xrange(1,len(my_topics)+1):
        key = str(i) + ' date ratio'
        plt.plot(df[key]) 
    plt.legend(['Cluster ' + str(i) for i in xrange(1,len(my_topics)+1)], loc = 'best',
              fancybox=True, shadow=True)
    plt.show()

# %%
plot_line_graph(grouped_by_date)

# %%
def stacked_graph_data_smooth(df):
    X = np.array(range(len(df.index.values)))
    X_smooth = np.linspace(X.min(),X.max(),150)
    
    store = []
    for i in xrange(1,len(my_topics)+1):
        key = str(i) + ' date ratio'
        values = np.array(list(df[key].values))
        smooth = list(spline(X,values,X_smooth))
        store.append(smooth)
    
    Y_smooth = np.array(store)
    
    return X_smooth, Y_smooth


def plot_stacked_graph_smooth(df):
    plt.figure(figsize = (20, 8))
    ax = plt.subplot(111)
    plt.stackplot(stacked_graph_data_smooth(df)[0], stacked_graph_data_smooth(df)[1], baseline='wiggle')
    plt.title('Headline Clusters', fontsize = 20)
    plt.axis('tight')
    ax.legend(['Cluster ' + str(i) + ':' + cluster_dict[str(i)] for i in xrange(1,len(my_topics)+1)], loc='upper center', bbox_to_anchor=(0.5, -0.10),
              fancybox=True, shadow=True, ncol=1)
    #plt.xticks(stacked_graph_data_smooth(df)[0])
    ticks = list(range(len(df.index.values)))
    labels = [pd.to_datetime(str(temp[i])).strftime('%b %d %Y') for i in range(len(list(grouped_by_date.index.values)))]
    plt.xticks(ticks, labels, rotation = 40, size='small')
    plt.yticks([],[])
    plt.show()

# %%
plot_stacked_graph_smooth(grouped_by_date)

# %%
def stacked_graph_data(df):
    store = []
    for i in xrange(1,len(my_topics)+1):
        key = str(i) + ' date ratio'
        values = list(df[key].values)
        store.append(values)

    Y = np.array(store)
    X = grouped_by_date.index.values
    return X, Y

def plot_stacked_graph(df):
    plt.figure(figsize = (20, 8))
    ax = plt.subplot(111)
    plt.stackplot(stacked_graph_data(df)[0], stacked_graph_data(df)[1], baseline='sym')
    plt.title('Headline Clusters', fontsize = 20)
    plt.axis('tight')
    ax.legend(['Cluster ' + str(i) + ':' + cluster_dict[str(i)] for i in xrange(1,len(my_topics)+1)], loc='upper center', bbox_to_anchor=(0.5, -0.05),
              fancybox=True, shadow=True, ncol=1)
    plt.yticks([],[])
    plt.show()

# %%
plot_stacked_graph(grouped_by_date)

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
import nltk
nltk.download('wordnet')

def lemmat(x):
    store = []
    for i in x:
        try:
            store.append(wordnet_lemmatizer.lemmatize(i))
        except UnicodeDecodeError:
            continue
    return store    

df['headline'] = df['headline'].apply(lemmat)
df.head()
